# %%
import mphot

# %%
instrument_efficiency_path = '../resources/systems/speculoos_Andor_iKon-L-936_-60.csv' # index in microns, efficiency of telescope+instrument as fraction
filter_path = '../resources/filters/I+z.csv' # index in microns, filter efficiency as fraction

name, system_response = mphot.generate_system_response(instrument_efficiency_path, filter_path)
# Out:
# `C:\Users\max_w\Documents\_Personal\_Studies\Physics BSc\semester 6\semester project\mphot\src\mphot\datafiles\system_responses\speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!

# %%
system_response.plot(xlabel='Wavelength (microns)', ylabel='System Response', title=name, ylim=(0, 1))
# Out:
# <Axes: title={'center': 'speculoos_Andor_iKon-L-936_-60_I+z'}, xlabel='Wavelength (microns)', ylabel='System Response'>

# %%
# sky properties
props_sky = {
    "pwv" : 2.5,        # PWV [mm]
    "airmass" : 1.1,    # airmass
    "seeing" : 1.35     # seeing (==FWHM) ["]
}

# instrument properties
props_instrument = {
    "name" : name,          # name to get SR/precision grid from file
    "plate_scale" : 0.35,   # pixel plate scale ["]
    "N_dc" : 0.2,           # dark current [e/pix/s]
    "N_rn" : 6.328,         # read noise [e_rms/pix]
    "well_depth" : 64000,   # well depth [e/pix]
    "well_fill" : 0.7,      # fractional value to fill central target pixel, assuming gaussian (width function of seeing^)
    "read_time" : 10.5,     # read time between images [s]
    "r0" : 0.5,             # radius of telescope's primary mirror [m]
    "r1" : 0.14,            # radius of telescope's secondary mirror [m]
    # "min_exp" : 0,          # optional, minimum exposure time [s]
    # "max_exp" : 120,        # optional, maximum exposure time [s]
    # "ap_rad" : 3            # optional, aperture radius [FWHM, seeing] for photometry -- 3 default == 7 sigma of Gaussian
}

# target properties
Teff = 2566       # [K]
distance = 12.5   # [pc]

# %%
# get the precision and components used to calculate it (generates grid if not already present)
result = mphot.get_precision(props_instrument, props_sky, Teff, distance)

mphot.display_results(result)
# Out:
# Progress: [#####---------------] 25.0%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 # get the precision and components used to calculate it (generates grid if not already present)
# ----> 2 result = mphot.get_precision(props_instrument, props_sky, Teff, distance)
#       4 mphot.display_results(result)
#
# File ~\Documents\_Personal\_Studies\Physics BSc\semester 6\semester project\mphot\src\mphot\core.py:806, in get_precision(props, props_sky, Teff, distance, binning, override_grid, SPCcorrection, N_sky, N_star, scn, exp_time, extended)
#     798 np.save(
#     799     Path(__file__).parent
#     800     / "grids"
#     801     / f"{name}_precisionGrid_flux_coords_{extended_str}.npy",
#     802     coords,
#     803 )
#     805 # generate radiance grid
# --> 806 coords, data = generate_radiance_grid(
#     807     Path(__file__).parent
#     808     / "datafiles"
#     809     / "system_responses"
#     810     / f"{name}_instrument_system_response.csv",
#     811     extended=extended,
#     812 )
#     814 # save output
#     815 np.save(
#     816     Path(__file__).parent
#     817     / "grids"
#     818     / f"{name}_precisionGrid_radiance_coords_{extended_str}.npy",
#     819     coords,
#     820 )
#
# File ~\Documents\_Personal\_Studies\Physics BSc\semester 6\semester project\mphot\src\mphot\core.py:491, in generate_radiance_grid(sResponse, extended)
#     489         for temperature in temperature_values:
#     490             atmosphere_flux = gridSauce[str(pwv) + "_" + str(airmass)]
# --> 491             response = simps(y=gridSauce[1] * atmosphere_flux, x=gridSauce.index)
#     493             atm_grid.append((pwv, airmass, temperature, response))
#     495 data = np.array([x[3] for x in atm_grid])
#
# File c:\Users\max_w\anaconda3\envs\astronomy\Lib\site-packages\scipy\integrate\_quadrature.py:536, in simpson(y, x, dx, axis)
#     534     result += val
#     535 else:
# --> 536     result = _basic_simpson(y, 0, N-2, x, dx, axis)
#     537 if returnshape:
#     538     x = x.reshape(saveshape)
#
# File c:\Users\max_w\anaconda3\envs\astronomy\Lib\site-packages\scipy\integrate\_quadrature.py:367, in _basic_simpson(y, start, stop, x, dx, axis)
#     365 hsum = h0 + h1
#     366 hprod = h0 * h1
# --> 367 h0divh1 = np.true_divide(h0, h1, out=np.zeros_like(h0), where=h1 != 0)
#     368 tmp = hsum/6.0 * (y[slice0] *
#     369                   (2.0 - np.true_divide(1.0, h0divh1,
#     370                                         out=np.zeros_like(h0divh1),
#    (...)    375                                               where=hprod != 0)) +
#     376                   y[slice2] * (2.0 - h0divh1))
#     377 result = np.sum(tmp, axis=axis)
#
# File c:\Users\max_w\anaconda3\envs\astronomy\Lib\site-packages\numpy\core\numeric.py:63, in _zeros_like_dispatcher(a, dtype, order, subok, shape)
#      38 array_function_dispatch = functools.partial(
#      39     overrides.array_function_dispatch, module='numpy')
#      42 __all__ = [
#      43     'newaxis', 'ndarray', 'flatiter', 'nditer', 'nested_iters', 'ufunc',
#      44     'arange', 'array', 'asarray', 'asanyarray', 'ascontiguousarray',
#    (...)     59     'MAY_SHARE_EXACT', '_get_promotion_state', '_set_promotion_state',
#      60     '_using_numpy2_behavior']
# ---> 63 def _zeros_like_dispatcher(a, dtype=None, order=None, subok=None, shape=None):
#      64     return (a,)
#      67 @array_function_dispatch(_zeros_like_dispatcher)
#      68 def zeros_like(a, dtype=None, order='K', subok=True, shape=None):
#
# KeyboardInterrupt:

# %%
# extract data
image_precision, binned_precision, components = result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # extract data
# ----> 2 image_precision, binned_precision, components = result
#
# NameError: name 'result' is not defined

# %%
image_precision # precision budget as fraction, x1000 for ppt
# Out:
# {'All': np.float64(0.0018594013224931464),
#  'Star': np.float64(0.0015193997816438612),
#  'Scintillation': np.float64(0.0006850773409832677),
#  'Sky': np.float64(0.0007880245951457461),
#  'Dark current': np.float64(9.605090685296679e-05),
#  'Read noise': np.float64(0.00022194161222999516)}

# %%
binned_precision # precision budget as fraction, x1000 for ppt
# Out:
# {'All': np.float64(0.0005259167624883394),
#  'Star': np.float64(0.00042975005149302546),
#  'Scintillation': np.float64(0.0001937686355632719),
#  'Sky': np.float64(0.00022288644136519523),
#  'Dark current': np.float64(2.7167229234003913e-05),
#  'Read noise': np.float64(6.277440633899071e-05)}

# %%
components # dictionary of components from calculation
# Out:
# {'name': 'andorSPC_-60_I+z',
#  'Teff [K]': 2566,
#  'distance [pc]': 12.5,
#  'N_star [e/s]': np.float64(11551.209732244162),
#  'star_flux [e/m2/s]': np.float64(17667.026959303585),
#  'scn [e_rms]': np.float64(296.75325008140226),
#  'npix': 230.81088883516844,
#  'ap_radius [pix]': 8.571428571428571,
#  'N_sky [e/pix/s]': np.float64(13.461907485031265),
#  'sky_radiance [e/m2/arcsec2/s]': np.float64(151.82320859470744),
#  'seeing [arcsec]': 1,
#  'pwv [mm]': 2.5,
#  'airmass': 1.1,
#  'plate_scale ["/pix]': 0.35,
#  'N_dc [e/pix/s]': 0.2,
#  'N_rn [e_rms/pix]': 6.328,
#  'A [m2]': 0.7238229473870883,
#  'r0 [m]': 0.5,
#  'r1 [m]': 0.14,
#  't [s]': np.float64(37.49975336520353),
#  'well_depth [e/pix]': 64000,
#  'well_fill': 0.7,
#  'binning [mins]': 10,
#  'read_time [s]': 10.5,
#  'nImages': np.float64(12.500064228141598)}

# %%
# extract exposure time
exposure_time = components['t [s]']
exposure_time
# Out:
# np.float64(37.49975336520353)
